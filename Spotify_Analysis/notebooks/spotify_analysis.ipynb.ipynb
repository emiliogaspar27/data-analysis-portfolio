# %% [markdown]
# **Pandas:** Biblioteca principal para análise de dados

# %%
import pandas as pd

# %%
df = pd.read_csv('spotify_analysis_dataset.csv')

# %%
df.head()
# Out:
#   track_id track_name     artist     album release_date  duration_ms  \
# 0  TRK1000     Song 0   Artist 7   Album 3   2010-01-01       240151
# 1  TRK1001     Song 1   Artist 4   Album 5   2010-01-02       253767
# 2  TRK1002     Song 2  Artist 13  Album 19   2010-01-03       244375
# 3  TRK1003     Song 3  Artist 11   Album 7   2010-01-04       299262
# 4  TRK1004     Song 4   Artist 8   Album 9   2010-01-05       256330
#
#    popularity  danceability  energy  loudness  speechiness  acousticness  \
# 0          70         0.037   0.349     -2.87        0.522         0.616
# 1          58         0.610   0.726    -22.87        0.770         0.635
# 2          85         0.503   0.897     -1.33        0.216         0.045
# 3          27         0.051   0.887     -1.46        0.623         0.375
# 4          65         0.279   0.780     -5.88        0.085         0.626
#
#    instrumentalness  liveness  valence   tempo
# 0             0.931     0.947    0.353  110.14
# ...

# %% [markdown]
# # Agrupando as informações gerais do Dataframe (SUMMARY)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track_id          50 non-null     object
#  1   track_name        50 non-null     object
#  2   artist            50 non-null     object
#  3   album             50 non-null     object
#  4   release_date      50 non-null     object
#  5   duration_ms       50 non-null     int64
#  6   popularity        50 non-null     int64
#  7   danceability      50 non-null     float64
#  8   energy            50 non-null     float64
#  9   loudness          50 non-null     float64
#  10  speechiness       50 non-null     float64
#  11  acousticness      50 non-null     float64
#  12  instrumentalness  50 non-null     float64
#  13  liveness          50 non-null     float64
#  14  valence           50 non-null     float64
#  15  tempo             50 non-null     float64
# ...

# %% [markdown]
# 1 - Quantidade de linhas e colunas do DataFrame

# %%
qtd_linhas, qtd_colunas = df.shape

# %%
print(f'Quantidade de linhas: {qtd_linhas}\nQuantidade de colunas: {qtd_colunas}')
# Out:
# Quantidade de linhas: 50
# Quantidade de colunas: 16

# %% [markdown]
# 2 - Quantidade de músicas

# %%
df['track_id'].count()

# %% [markdown]
# 3 - Quantidade de artistas

# %%
df['artist'].nunique()

# %% [markdown]
# 4 - Quantidade de Álbuns

# %%
df['album'].nunique()

# %% [markdown]
# 5 - Popularidade Máxima Alcançada

# %%
df['popularity'].max()

# %% [markdown]
# 5.1 - Popularidade Mínima Alcançada

# %%
df['popularity'].min()

# %% [markdown]
# 6 - Média da duração das músicas

# %%
media = df['duration_ms'].mean()

# %%
media = (lambda x: f"{int(x)//60000}:{(int(x)%60000)//1000:02d}")(media)

# %%
media

# %% [markdown]
# Criando a coluna **'duration_min:seg'** a partir coluna **'duration_ms'** para uma melhor interpretação dos dados(Formatando os dados para um formato mais legível).

# %%
df['duration_min:seg'] = df['duration_ms'].apply(lambda x: f"{x//60000}:{(x%60000)//1000:02d}")

# %% [markdown]
# Exibindo as últimas linhas do novo DataFrame criado.

# %%
df[['duration_min:seg']].tail()

# %% [markdown]
# # Coletando os INSIGHTS

# %% [markdown]
# 1 - Qual é o artista que mais trabalhou musicalmente?

# %%
artista_mais_lançou_musicas = df['artist'].value_counts().index[0]
artista_mais_lançou_musicas
# Out:
# 'Artist 12'

# %%
df['artist'].value_counts().iloc[0]
# Out:
# 7

# %%
df.loc[df['artist'] == artista_mais_lançou_musicas]

# %% [markdown]
# 2 - Qual é a música com maior duração de tempo?

# %%
df.loc[df['duration_ms'].idxmax(), ['track_name', 'duration_min:seg']]

# %% [markdown]
# 2.1 - Qual é a música com menor duração de tempo?

# %%
df.loc[df['duration_ms'].idxmin(), ['track_name', 'duration_min:seg']]

# %% [markdown]
# 3 - Qual é a mais recente e a mais antiga música?

# %% [markdown]
# Música mais recente.

# %%
df.loc[df['release_date'].idxmax(), ['track_name', 'release_date']]

# %% [markdown]
# Música mais antiga.

# %%
df.loc[df['release_date'].idxmin(), ['track_name', 'release_date']]

# %% [markdown]
# 4 - Qual é a música mais popular actualmente?

# %%
df.loc[df['popularity'].idxmax(), ['track_name', 'popularity']]

# %% [markdown]
# 5 - Quais são as músicas mais difíceis de Dançar?

# %%
df.nsmallest(3,'danceability')[['track_name', 'danceability']]

# %% [markdown]
# 6 - Quais são os álbuns com os maiores números de faixas?

# %%
 df['album'].value_counts().head(3)
