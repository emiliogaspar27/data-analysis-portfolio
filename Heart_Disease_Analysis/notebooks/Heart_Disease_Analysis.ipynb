# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # Agrupando as informações gerais do Dataframe (SUMMARY)

# %% [markdown]
# Informações gerais do DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# Quantidade de casos positivos e negativos presentes

# %%
df['target'].value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
sns.countplot(x='target', data=df)
plt.title('Distribuição de Casos Negativos/Positivos')
plt.show()

# %% [markdown]
# Idade mínima, média e máxima dos pacientes

# %%
print(f"Idade Máxima: {df['age'].max()}\nIdade Média: {df['age'].mean():.0f}\nIdade Mínima: {df['age'].min()}")
# Out:
# Idade Máxima: 77
# Idade Média: 54
# Idade Mínima: 29

# %% [markdown]
# Distribuição percentual de pacientes por sexo (0 - Feminino/ 1 - Masculino)

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.countplot(x='sex', data=df)
plt.title('Distribuição percentual de pacientes por sexo (0 - Feminino/ 1 - Masculino)')
plt.show()

# %% [markdown]
# Qual é a distribuição dos tipos de dor no peito?

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
sns.countplot(x='cp', data=df)
plt.title('Distribuição dos tipos de dor no peito')
plt.show()

# %% [markdown]
# Qual é a pressão arterial média em repouso dos pacientes?

# %%
print(f"{df['trestbps'].mean():.0f}")
# Out:
# 132

# %% [markdown]
# Qual é o nível médio de colestero?

# %%
print(f"{df['chol'].mean():.0f}")
# Out:
# 246

# %% [markdown]
# Quantos pacientes têm açúcar no sangue em jejum elevado?

# %%
df['fbs'].value_counts().iloc[1]
# Out:
# 153

# %% [markdown]
# Quais são os resultados mais comuns no eletrocardiograma em repouso?

# %%
df['restecg'].value_counts()
# Out:
# restecg
# 1    513
# 0    497
# 2     15
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='restecg', data=df)
plt.title('Resultados mais comuns no eletrocardiograma em repouso')
plt.show()

# %% [markdown]
# Qual é a frequência cardíaca máxima média atingida pelos pacientes?

# %%
round(df['thalach'].mean())
# Out:
# 149

# %% [markdown]
# Quantos pacientes apresentam angina induzida por exercício?

# %%
df['exang'].value_counts().iloc[1]
# Out:
# 345

# %% [markdown]
# Qual é a média de depressão do segmento ST?

# %%
round(df['oldpeak'].mean())
# Out:
# 1

# %% [markdown]
# Qual é a distribuição das inclinações do segmento ST?

# %%
df['slope'].value_counts()
# Out:
# slope
# 1    482
# 2    469
# 0     74
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
sns.countplot(x='slope', data=df)
plt.title('Distribuição das inclinações do segmento ST')
plt.show()

# %% [markdown]
# Quantos pacientes têm cada número de vasos principais coloridos por fluoroscopia?

# %%
df['ca'].value_counts()
# Out:
# ca
# 0    578
# 1    226
# 2    134
# 3     69
# 4     18
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
sns.countplot(x='ca', data=df)
plt.title('Número de vasos principais coloridos por fluoroscopia')
plt.show()

# %% [markdown]
# Qual é a distribuição dos tipos de thalassemia?

# %%
df['thal'].value_counts()
# Out:
# thal
# 2    544
# 3    410
# 1     64
# 0      7
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,4))
sns.countplot(x='thal', data=df)
plt.title('Distribuição dos tipos de thalassemia')
plt.show()

# %% [markdown]
# # Coletando os INSIGHTS

# %% [markdown]
# A idade influencia a probabilidade de doença cardíaca?

# %%
round(df['age'].corr(df['target']),2)
# Out:
# -0.23

# %% [markdown]
# O sexo tem relação com a ocorrência de doença cardíaca?

# %%
round(df['sex'].corr(df['target']),2)
# Out:
# -0.28

# %% [markdown]
# Existe algum tipo de dor no peito mais associado à doença cardíaca?

# %%
round(df['cp'].corr(df['target']),2)
# Out:
# 0.43

# %% [markdown]
# Pacientes com pressão arterial elevada têm mais risco de doença cardíaca?

# %%
round(df['trestbps'].corr(df['target']),2)
# Out:
# -0.14

# %% [markdown]
# Existe relação entre nível de colesterol e doença cardíaca?

# %%
round(df['chol'].corr(df['target']),2)
# Out:
# -0.1

# %% [markdown]
# O açúcar no sangue em jejum elevado está associado à doença cardíaca?

# %%
round(df['fbs'].corr(df['target']),2)
# Out:
# -0.04

# %% [markdown]
# Resultados anormais do eletrocardiograma aumentam o risco?

# %%
round(df['restecg'].corr(df['target']),2)
# Out:
# 0.13

# %% [markdown]
# Pacientes com frequência cardíaca máxima baixa ou alta têm mais doença cardíaca?

# %%
round(df['thalach'].corr(df['target']),2)
# Out:
# 0.42

# %% [markdown]
# Existe correlação entre depressão do segmento ST e doença cardíaca?

# %%
round(df['oldpeak'].corr(df['target']),2)
# Out:
# -0.44

# %% [markdown]
# A angina induzida por exercício é um forte indicador de doença cardíaca?

# %%
round(df['exang'].corr(df['target']),2)
# Out:
# -0.44

# %% [markdown]
# A inclinação do segmento ST pode indicar risco de doença cardíaca?

# %%
round(df['slope'].corr(df['target']),2)
# Out:
# 0.35

# %% [markdown]
# O número de vasos principais influencia a presença de doença cardíaca?

# %%
round(df['ca'].corr(df['target']),2)
# Out:
# -0.38

# %% [markdown]
# Algum tipo de thalassemia está mais associado à doença cardíaca?

# %%
round(df['thal'].corr(df['target']),2)
# Out:
# -0.34

# %% [markdown]
# - #### Quais são os principais fatores de risco combinados para doença cardíaca (idade, sexo, colesterol, pressão, etc.)?

# %% [markdown]
# Os principais fatores de risco combinados para doença cardíaca incluem o tipo de dor no peito, frequência cardíaca máxima, inclinação do segmento ST, número de vasos principais coloridos e tipo de thalassemia, que apresentam as associações mais fortes com a presença de doença. Variáveis como idade, sexo, pressão arterial, colesterol, açúcar no sangue e resultados do ECG têm efeitos isolados mais fracos, mas podem contribuir quando analisadas em conjunto com os fatores principais. Em resumo, a combinação dessas variáveis fornece a melhor predição do risco de doença cardíaca neste dataset.
